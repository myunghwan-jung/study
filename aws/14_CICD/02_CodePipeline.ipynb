# %% [markdown]
# # AWS CodePipeline
# - AWS CodePipeline은 빠르고 안정적인 어플리케이션 및 인프라 업데이트를 위해 릴리스 파이프라인을 자동화하는데 도움이 되는 완전 관리형 지속적 전달 서비스입니다
# - 전체 프로세스 오케스트레이션
# - 서버리스
# - 이벤트 기반 운영 가능
# - 다양한 AWS 서비스 연동 가능
# - 다양한 외부 서비스 연동 가능(Jenkins 등)

# %% [markdown]
# ## 주요개념
# - 파이프라인 : 여러 배포 과정으로 구성된 워크플로우
# - 스테이지 : 격리된 환경에서 작업을 수행하는 논리적 단위
#     - 다양한 작업으로 구성
#     - 아티팩트를 받아서 아티팩트 기반으로 정해진 작업을 수행
#     - 제한 없는 숫자로 동시에 다양한 작업을 수행 가능
# - 작업 : 각 스테이지에서 수행하는 작업 (예 : 소스 가져오기, 빋르, 테스트, 배포, 인가 대기 등)
# - 아티팩트 : 각 스테이지에 인풋으로 제공되는 데이터
#     - 코드, 디펜던시 파일, 템플릿 등
#     - 인풋 아티팩트 : 각 스테이지에서 작업에 사용하는 기반 파일
#     - 아웃풋 아티팩트 : 스테이지의 작업 결과물로 다른 스테이지로 전달하거나 배포되는 파일
#     - S3에 저장
# - 트랜지션 : 각 스테이지간의 이동 포인트
#     - 비활성화 가능
# - 소스 연결 : 외부의 소스 레포지토리와 연결하는 단위
#     - Bitbucket, Github, Github Enterprise Server, GitLab, GitLab Self-Managed 지원

# %% [markdown]
# ### 데모 - 코드 파이프라인
# - 깃헙에 레포 생성
# - 테스트 스크립트 생성
# - 파이프라인 생성, 내용 출력 테스트
# 1. 레포지토리에 스크립트 파일 생성
# 2. 코드 파이프라인 생성
#     - 커스텀
#     - 깃허브와 연결
#     - 빌드 스테이지에 스크립트 입력
# 3. 레포 코드를 바꿔보자
