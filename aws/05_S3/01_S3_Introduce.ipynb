# %% [markdown]
# # S3 소개
# - Amazon Simple Storage Service(Amazon S3)는 업계 최고의 확장성과 데이터 가용성 및 보안과 성능을 제공하는 객체 스토리지 서비스입니다. Amazon S3는 99.999999999%의 내구성을 제공하도록 설계되었으며, 전 세계 기업의 수백만 어플리케이션을 위한 데이터를 저장합니다.
# - AWS에서 제공하는 오브젝트 스토리지 서비스
# - 파일을 저장하고 활용하고 싶을 때 사용 (미디어, 로그, 소스코드, 파일, 백업)
# - Static Hosting 기능으로 서버 없이 웹페이지를 제공하고 싶을 때 사용
# - 기타 파일을 관리하고 싶을 때 사용
# - 99.999999999%의 내구성, 99.99%의 가용성을 가진 분산 스토리지로 파일 저장
#     - 내구성은 파일을 잃어버리지 않는 기능
#     - 가용성은 유저가 원할 때 파일을 가져갈 수 있는 기능
# - 다양한 기능
#     - Presigned URL : 제한된 사람에게만 전달, 버전 관리, 권한 관리
#     - 주기적인 복제, 일정기간 파일 삭제 방지, 버전 관리, 암호화 등

# %% [markdown]
# ## 파일 스토리지 vs 오브젝트 스토리지
# - 파일 스토리지 : 파일을 계층구조로 관리
#     - 빠르게 찾고 업데이트 작업 가능
#     - 확장이 제한적
# - 오브젝트 스토리지 : 파일을 오브젝트(데이터, 메타데이터, 아이디)단위로 관리
#     - 정확한 경로를 알아야 찾기 가능
#     - 확장이 쉬움
# - 간단한 구분
#     - 게임 설치해서 사용 가능하면 파일 스토리지
#     - 웹하드/구글 드라이브 처럼 게임 설치 못하면 오브젝트 스토리지
