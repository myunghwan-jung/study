# %% [markdown]
# # EC2 Instance
# - EC2에서 컴퓨팅을 담당
#     - 다양한 유형과 크기로 구성
#     - 저장을 담당하는 EBS와 네트워크로 연결
# - 저장 방법에 따라 두 가지로 분류
#     - EBS 연동
#     - 인스턴스 스토어
# - 하나의 가용영역(AZ)에 존재

# %% [markdown]
# ## 인스턴스 유형
# - 인스턴스의 역할에 따라 CPU, 메모리, 스토리지, 네트워크 등을 조합한 구성(패밀리라고도 부름)
# - 각 인스턴스 유형 별로 사용 목적에 따라 최적화
#     - 예 : 메모리 위주, 그래픽카드 위주 등등
# - 유형 별로 이름 존재
#     - 예 : t패밀리, g패밀리
#     - 같은 유형의 인스턴스들을 인스턴스 패밀리라 부름
# - 타입 별 세대별로 숫자 부여
#     - 예 : m5 = m인스턴스의 5세대
# - 아키텍쳐 및 프로세서 / 추가 기술에 따라 접미사가 붙는다
#     - 예 : c7gn = c 인스턴스 패밀리 중 AWS Graviton 프로세서를 사용(g) + Network Optimized(n) + 7세대 = c7gn

# %% [markdown]
# ## 인스턴스 크기
# - 같은 인스턴스 패밀리 안에서도 다양한 크기의 인스턴스가 존재
# - 인스턴스의 CPU 개수, 메모리 크기, 성능 등으로 구분
# - 크기가 클 수록 더 많은 메모리, CPU, 네트워크 대역폭, EBS와 통신 가능한 대역폭
